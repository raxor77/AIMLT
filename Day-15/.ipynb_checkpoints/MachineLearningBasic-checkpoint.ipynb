# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data={'Hours':[1,2,3,4,5,6,7,8],
     'Marks':[25,35,45,50,55,65,70,80]}
df=pd.DataFrame(data)

# %%
#step 3 :Define Features and Target
X=df[['Hours']]
Y=df[['Marks']]

# %%
#step 4 :Split Data into Train & Test sets
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.8,random_state=0)
print('Training Samples : ',len(X_train))
print('Testing Samples : ',len(X_test))
# Out:
# Training Samples :  1
# Testing Samples :  7

# %%
#step 5 : create the model and step 6 : train the model
model=LinearRegression()
model.fit(X_train,Y_train)
print('Model Train successful')
# Out:
# Model Train successful

# %%
Y_pred=model.predict(X_test)
print(Y_test.values)
print(X_test)
print('Actual : ',list(Y_test.values))
print('Predicted : ',list(Y_pred))
# Out:
# [[70]
#  [45]
#  [35]
#  [80]
#  [50]
#  [25]
#  [65]]
#    Hours
# 6      7
# 2      3
# 1      2
# 7      8
# 3      4
# 0      1
# 5      6
# Actual :  [array([70]), array([45]), array([35]), array([80]), array([50]), array([25]), array([65])]
# Predicted :  [array([55.]), array([55.]), array([55.]), array([55.]), array([55.]), array([55.]), array([55.])]
